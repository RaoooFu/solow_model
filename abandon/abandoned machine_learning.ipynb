# %% [markdown]
# Step 1: Load dataset into python

# %%
from sklearn.datasets import  fetch_california_housing
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor

from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
import pandas as pd

# %%
file_path='/Users/home/Desktop/Ironhack/Group Assignment/machine_learning/west_eu.xlsx'

# %%
west_eu = pd.read_excel(file_path)

# %%
west_eu
# Out:
#     Year          Region  gdp growth by year  \
# 0   2010  Western Europe                2.12
# 1   2011  Western Europe                1.72
# 2   2012  Western Europe               -0.35
# 3   2013  Western Europe                0.37
# 4   2014  Western Europe                1.80
# 5   2015  Western Europe                2.06
# 6   2016  Western Europe                1.84
# 7   2017  Western Europe                2.67
# 8   2018  Western Europe                1.69
# 9   2019  Western Europe                1.62
# 10  2020  Western Europe               -6.37
# 11  2021  Western Europe                6.55
# 12  2022  Western Europe                3.70
# 13  2023  Western Europe                0.52
# 14  2024  Western Europe                0.91
# 15  2025  Western Europe                0.92
# 16  2026  Western Europe                1.37
# 17  2027  Western Europe                1.55
# 18  2028  Western Europe                1.48
# 19  2029  Western Europe                1.45
# ...

# %%
train_west_eu=west_eu[west_eu['Year']<=2024]

# %%
train_west_eu
# Out:
#     Year          Region  gdp growth by year  \
# 0   2010  Western Europe                2.12
# 1   2011  Western Europe                1.72
# 2   2012  Western Europe               -0.35
# 3   2013  Western Europe                0.37
# 4   2014  Western Europe                1.80
# 5   2015  Western Europe                2.06
# 6   2016  Western Europe                1.84
# 7   2017  Western Europe                2.67
# 8   2018  Western Europe                1.69
# 9   2019  Western Europe                1.62
# 10  2020  Western Europe               -6.37
# 11  2021  Western Europe                6.55
# 12  2022  Western Europe                3.70
# 13  2023  Western Europe                0.52
# 14  2024  Western Europe                0.91
#
#     real private consumption growth by year  \
# 0                                      1.24
# 1                                      0.12
# 2                                     -0.32
# 3                                      0.22
# ...

# %%
test_west_eu
# Out:
#     Year          Region  gdp growth by year  \
# 15  2025  Western Europe                0.92
# 16  2026  Western Europe                1.37
# 17  2027  Western Europe                1.55
# 18  2028  Western Europe                1.48
# 19  2029  Western Europe                1.45
# 20  2030  Western Europe                1.46
# 21  2031  Western Europe                1.42
# 22  2032  Western Europe                1.35
# 23  2033  Western Europe                1.33
# 24  2034  Western Europe                1.30
# 25  2035  Western Europe                1.29
#
#     real private consumption growth by year  \
# 15                                     1.32
# 16                                     1.42
# 17                                     1.44
# 18                                     1.45
# 19                                     1.48
# 20                                     1.49
# 21                                     1.46
# 22                                     1.35
# ...

# %% [raw]
# Step 2: Train test splits

# %%
x_train_west_eu=train_west_eu.drop(columns=['Retail Volume(in units)','Year','Region'])
y_train_west_eu=train_west_eu['Retail Volume(in units)']

# %%
test_west_eu=west_eu[west_eu['Year']>2024]

# %%
x_train_west_eu
# Out:
#     gdp growth by year  real private consumption growth by year  \
# 0                 2.12                                     1.24
# 1                 1.72                                     0.12
# 2                -0.35                                    -0.32
# 3                 0.37                                     0.22
# 4                 1.80                                     1.33
# 5                 2.06                                     2.24
# 6                 1.84                                     2.15
# 7                 2.67                                     1.90
# 8                 1.69                                     1.53
# 9                 1.62                                     1.26
# 10               -6.37                                    -8.47
# 11                6.55                                     5.08
# 12                3.70                                     5.30
# 13                0.52                                     0.59
# ...

# %% [raw]
# y_train_west_eu

# %%
KNN Regressor - modeling

# %%
knn = KNeighborsRegressor(n_neighbors=10)

# %%
x_test_west_eu=test_west_eu.drop(columns=['Retail Volume(in units)','Year','Region'])

# %%
years_future = test_west_eu['Year'].values
years_future
# Out:
# array([2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034, 2035])

# %%
#train the model 
knn.fit(x_train_west_eu, y_train_west_eu)
# Out:
# KNeighborsRegressor(n_neighbors=10)

# %%
y_pred_west_eu
# Out:
# array([412505.65, 411974.04, 411974.04, 411974.04, 411974.04, 411974.04,
#        411974.04, 411974.04, 411974.04, 411974.04, 411974.04])

# %%
y_pred_west_eu = knn.predict(x_test_west_eu)

# %%
predictions = pd.DataFrame({
    'Year': years_future,
    'Predicted Retail Volume': y_pred_west_eu
})

print(predictions)
# Out:
#     Year  Predicted Retail Volume
# 0   2025                412505.65
# 1   2026                411974.04
# 2   2027                411974.04
# 3   2028                411974.04
# 4   2029                411974.04
# 5   2030                411974.04
# 6   2031                411974.04
# 7   2032                411974.04
# 8   2033                411974.04
# 9   2034                411974.04
# 10  2035                411974.04

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
mse = mean_squared_error(y_test_west_eu, y_pred_west_eu)
mae = mean_absolute_error(y_test_west_eu, y_pred_west_eu)
r2 = r2_score(y_test_west_eu, y_pred_west_eu)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 mse = mean_squared_error(test_west_eu, y_pred_west_eu)
#       2 mae = mean_absolute_error(test_west_eu, y_pred_west_eu)
#       3 r2 = r2_score(test_west_eu, y_pred_west_eu)
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
# ...
